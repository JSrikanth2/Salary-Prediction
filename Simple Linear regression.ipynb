# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

# %%
df = pd.read_csv('/content/Salary.csv')
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
plt.scatter(df['YearsExperience'], df['Salary'])
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.show()

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
y = df['Salary']

# %%
x = df['YearsExperience']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size=0.7, random_state=2529)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((24,), (11,), (24,), (11,))

# %%
x_train = x_train.values.reshape(-1, 1)
x_test = x_test.values.reshape(-1, 1)

# %%
model = LinearRegression()

# %%
from sklearn.preprocessing import StandardScaler
model2 = StandardScaler()

# %%
model2.fit(x_train,y_train)
# Out:
# StandardScaler()

# %%
x_train = model2.fit_transform(x_train)
x_test = model2.transform(x_test)
y_pred2 = model.predict(x_test)

# %%
y_pred2
# Out:
# array([25565.46162718, 38525.4664255 , 41017.77504056, 40270.08245604,
#        15596.22716693, 27310.07765772, 29303.92454977, 17839.30492048,
#        17340.84319747, 27060.84679621, 16094.68888994])

# %%
mean_absolute_percentage_error(y_test,y_pred2)
# Out:
# 0.6530824021794741

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([8670.47923158])

# %%
model.intercept_
# Out:
# np.float64(28618.53968062705)

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([ 74572.07960798, 119658.57161219, 128329.05084376, 125727.90707429,
#         39890.16268168,  80641.41507009,  87577.79845535,  47693.5939901 ,
#         45959.49814378,  79774.36714693,  41624.25852799])

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 4855.645441556877

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.07668979278321196

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 36457720.24723787
